# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AvgPool2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

def load_train():
    # Assuming 'features_train' and 'target_train' are your dataset variables
    # Replace the paths with the correct paths to your dataset files
    features_train = np.load('/datasets/fashion_mnist/train_features.npy')
    target_train = np.load('/datasets/fashion_mnist/train_target.npy')
    
    # Normalize and reshape the data
    features_train = features_train.reshape(-1, 28, 28, 1) / 255.0
    target_train = to_categorical(target_train)
    
    return features_train, target_train

def create_model(input_shape):
    model = Sequential([
        Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(10, activation='softmax')
    ])
    
    optimizer = Adam(lr=0.001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def train_model(model, features_train, target_train, epochs=10, batch_size=256):
    model.fit(features_train, target_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=1)
    return model

# Load the training data
features_train, target_train = load_train()

# Create the model
model = create_model(features_train.shape[1:])

# Train the model
model = train_model(model, features_train, target_train, epochs=10, batch_size=256)

# Save the model, if desired
# model.save('fashion_mnist_model.h5')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AvgPool2D, Dropout
#       4 from tensorflow.keras.optimizers import Adam
#
# File c:\Users\cosmi\anaconda3\Lib\site-packages\keras\api\_v2\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.api._v2.keras import __internal__
#       4 from keras.api._v2.keras import activations
#       5 from keras.api._v2.keras import applications
#
# File c:\Users\cosmi\anaconda3\Lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# ...
